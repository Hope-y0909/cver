# %%
import numpy as np
import cv2 as cv
from matplotlib  import pyplot as plot

# %%
img=plot.imread("test.jpg")
#img=cv.imread("test.jpg")
plot.imshow(img)
plot.xticks([])
plot.yticks([])
plot.show()
